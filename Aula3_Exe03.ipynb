# %% [markdown]
# <a href="https://colab.research.google.com/github/melinalessa/AnaliseExploratoriaPandas/blob/main/Aula3_Exe03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importar a biblioteca

# %%
import pandas as pd

# %% [markdown]
# Ler o DATASET e armazenar em uma variavel

# %%
df= pd.read_csv('dataset.csv', sep= ",")

# %% [markdown]
# Informacoes gerais do DATASET

# %%
df.describe()
# Out:
#             Idade      Rating
# count  100.000000  100.000000
# mean    23.400000    5.625700
# std      4.042701    2.601318
# min     17.000000    1.150000
# 25%     20.000000    3.487500
# 50%     24.000000    5.890000
# 75%     27.250000    7.837500
# max     29.000000    9.990000

# %% [markdown]
# Mostrar as 3 primeiras linhas do DATASET

# %%
df.head(3)
# Out:
#         Nome  Idade  Rating Renda
# 0       Sato     18    3.66     D
# 1     Suzuki     20    3.51     D
# 2  Takahashi     26    9.73     A

# %% [markdown]
# Ler as 2 ultimas linhas do dataset

# %%
df.tail(2)
# Out:
#         Nome  Idade  Rating Renda
# 98      Arai     28    8.98     A
# 99  Watanabe     29    4.81     B

# %% [markdown]
# Ler a quantidade de linhas e colunas

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# Obter informacoes das colunas com o metodo info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    100 non-null    object
#  1   Idade   100 non-null    int64
#  2   Rating  100 non-null    float64
#  3   Renda   100 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ KB
