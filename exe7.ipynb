# %% [markdown]
# <a href="https://colab.research.google.com/github/melinalessa/AnaliseExploratoriaPandas/blob/main/exe7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando Biblioteca

# %%
import pandas as pd

# %% [markdown]
# Criar Variável

# %%
df= pd.read_csv('FAOSTAT_data_12-5-2020.csv')
df
# Out:
#    Domain Code Domain  Area Code                      Area  Element Code  \
# 0           QC  Crops          9                 Argentina          5419
# 1           QC  Crops          9                 Argentina          5419
# 2           QC  Crops          9                 Argentina          5419
# 3           QC  Crops          9                 Argentina          5510
# 4           QC  Crops          9                 Argentina          5510
# ..         ...    ...        ...                       ...           ...
# 61          QC  Crops        231  United States of America          5419
# 62          QC  Crops        231  United States of America          5419
# 63          QC  Crops        231  United States of America          5510
# 64          QC  Crops        231  United States of America          5510
# 65          QC  Crops        231  United States of America          5510
#
#        Element  Item Code      Item  Year Code  Year    Unit     Value Flag  \
# ...

# %% [markdown]
# Informacoes sobre

# %% [markdown]
# Renomear os titulos das colunas

# %%
df.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value', 'Flag',
#        'Flag Description'],
#       dtype='object')

# %%
df = pd.DataFrame(df)

# %%
df.rename(columns={'Domain Code':'Código do Domínio', 'Domain':'Domínio', 'Area Code':'Código de Área', 'Area':'Área', 'Element Code':'Código do Elemento', 'Element':'Elemento', 'Item Code':'Item do Código', 'Item':'Item', 'Year Code':'Código do Ano', 'Year':'Ano', 'Unit':'Unidade', 'Value':'Valor', 'Flag':'Sinalizador', 'Flag Description':'Descrição da Sinalizador'})
# Out:
#    Código do Domínio Domínio  Código de Área                      Área  \
# 0                 QC   Crops               9                 Argentina
# 1                 QC   Crops               9                 Argentina
# 2                 QC   Crops               9                 Argentina
# 3                 QC   Crops               9                 Argentina
# 4                 QC   Crops               9                 Argentina
# ..               ...     ...             ...                       ...
# 61                QC   Crops             231  United States of America
# 62                QC   Crops             231  United States of America
# 63                QC   Crops             231  United States of America
# 64                QC   Crops             231  United States of America
# 65                QC   Crops             231  United States of America
#
#     Código do Elemento    Elemento  Item do Código      Item  Código do Ano  \
# ...
