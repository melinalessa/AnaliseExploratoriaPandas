# %% [markdown]
# <a href="https://colab.research.google.com/github/melinalessa/AnaliseExploratoriaPandas/blob/main/Aula3_Exe02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importar biblioteca

# %%
import pandas as pd

# %% [markdown]
# Criar uma variável

# %%
df= pd.read_csv('FAOSTAT_data_12-5-2020.csv', sep= ",")

# %% [markdown]
# Ver quantidade de linhas e colunas

# %%
df.shape
# Out:
# (66, 14)

# %% [markdown]
# Ver informações do meu conjunto de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       66 non-null     object
#  1   Domain            66 non-null     object
#  2   Area Code         66 non-null     int64
#  3   Area              66 non-null     object
#  4   Element Code      66 non-null     int64
#  5   Element           66 non-null     object
#  6   Item Code         66 non-null     int64
#  7   Item              66 non-null     object
#  8   Year Code         66 non-null     int64
#  9   Year              66 non-null     int64
#  10  Unit              66 non-null     object
#  11  Value             66 non-null     int64
#  12  Flag              43 non-null     object
#  13  Flag Description  66 non-null     object
# dtypes: int64(6), object(8)
# memory usage: 7.3+ KB

# %% [markdown]
# Ver os tipos de dados

# %%
df.dtypes
# Out:
# Domain Code         object
# Domain              object
# Area Code            int64
# Area                object
# Element Code         int64
# Element             object
# Item Code            int64
# Item                object
# Year Code            int64
# Year                 int64
# Unit                object
# Value                int64
# Flag                object
# Flag Description    object
# dtype: object

# %% [markdown]
# Renomear colunas

# %%
df.rename(columns={
    "Domain Code": "Código Dominio",
    "Domain": "Domínio",
    "Area Code": "Codigo de Area",
    "Element Code": "Codigo do Produto",
    "Element": "Produto",
    "Item Code": "Codigo do Item",
    "Item": "Item",
    "Year Code": "Codigo do Ano",
    "Year": "Ano",
    "Unit": "Unidade",
    "Value": "Valor",
    "Flag": "Localizacao",
    "Flag Description": "Descricao da Localizacao"
})
# Out:
#    Código Dominio Domínio  Codigo de Area                      Area  \
# 0              QC   Crops               9                 Argentina
# 1              QC   Crops               9                 Argentina
# 2              QC   Crops               9                 Argentina
# 3              QC   Crops               9                 Argentina
# 4              QC   Crops               9                 Argentina
# ..            ...     ...             ...                       ...
# 61             QC   Crops             231  United States of America
# 62             QC   Crops             231  United States of America
# 63             QC   Crops             231  United States of America
# 64             QC   Crops             231  United States of America
# 65             QC   Crops             231  United States of America
#
#     Codigo do Produto     Produto  Codigo do Item      Item  Codigo do Ano  \
# ...
